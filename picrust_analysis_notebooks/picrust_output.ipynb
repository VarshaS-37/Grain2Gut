# %% [markdown]
# <a href="https://colab.research.google.com/github/VarshaS-37/Millet_derived_LAB_analysis/blob/main/picrust_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required tools
# !apt-get install -y cmake build-essential
# !pip install biom-format

# Install VSEARCH
# !wget https://github.com/torognes/vsearch/releases/download/v2.21.1/vsearch-2.21.1-linux-x86_64.tar.gz
# !tar -xvzf vsearch-2.21.1-linux-x86_64.tar.gz
# !cp vsearch-2.21.1-linux-x86_64/bin/vsearch /usr/local/bin/
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 72.0 MB/s eta 0:00:00
# ...
# --2025-09-17 05:54:19--  https://github.com/torognes/vsearch/releases/download/v2.21.1/vsearch-2.21.1-linux-x86_64.tar.gz
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !vsearch --cluster_fast millet.fasta \
         --id 0.97 \
         --centroids millet_otus.fasta \
         --uc millet_clusters.uc
# Out:
# vsearch v2.21.1_linux_x86_64, 12.7GB RAM, 2 cores
# https://github.com/torognes/vsearch
#
# Reading file millet.fasta 100%
# 4445 nt in 4 seqs, min 818, max 1220, avg 1111
# Masking 100%
# Sorting by length 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 4 Size min 1, max 1, avg 1.0
# Singletons: 4, 100.0% of seqs, 100.0% of clusters

# %%
# !vsearch --usearch_global millet.fasta \
         --db millet_otus.fasta \
         --id 0.97 \
         --otutabout millet_otu_table.txt
# Out:
# vsearch v2.21.1_linux_x86_64, 12.7GB RAM, 2 cores
# https://github.com/torognes/vsearch
#
# Reading file millet_otus.fasta 100%
# 4445 nt in 4 seqs, min 818, max 1220, avg 1111
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 4 of 4 (100.00%)
# Writing OTU table (classic) 100%

# %%
# !wget -nc https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2025-09-17 09:24:33--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162129736 (155M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 154.62M   170MB/s    in 0.9s
#
# 2025-09-17 09:24:34 (170 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [162129736/162129736]
#
# PREFIX=/usr/local
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
# ...

# %%
import sys
sys.path.append('/usr/local/lib/python3.10/site-packages')

# %%
# !conda config --set channel_priority strict
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r

# %%
# !conda create -y -n picrust2_env python=3.8
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# done
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/picrust2_env
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.9.9   |       h06a4308_0         127 KB
#     libzlib-1.3.1              |       hb25bd0a_0          59 KB
#     pip-24.2                   |   py38h06a4308_0         2.2 MB
#     python-3.8.20              |       he870216_0        23.8 MB
#     setuptools-75.1.0          |   py38h06a4308_0         1.7 MB
#     wheel-0.44.0               |   py38h06a4308_0         108 KB
#     zlib-1.3.1                 |       hb25bd0a_0          96 KB
#     ------------------------------------------------------------
# ...

# %%
# !conda install -y -n picrust2_env -c conda-forge -c bioconda picrust2=2.5.1
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - bioconda
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/picrust2_env
#
#   added / updated specs:
#     - picrust2=2.5.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _r-mutex-1.0.1             |      anacondar_1           3 KB  conda-forge
#     alsa-lib-1.1.5             |    h516909a_1002         544 KB  conda-forge
#     binutils_impl_linux-64-2.39|       he00db2b_1         4.7 MB  conda-forge
#     binutils_linux-64-2.39     |      h5fc0e48_13          27 KB  conda-forge
#     biom-format-2.1.12         |   py38h26c90d9_2        10.5 MB  conda-forge
#     bwidget-1.10.1             |       ha770c72_1         127 KB  conda-forge
#     bzip2-1.0.8                |       hda65f42_8         254 KB  conda-forge
# ...

# %%
# %%bash
# sed 's/ .*$//' /content/millet.fasta> /content/cleaned_millet.fasta

# %%
# !conda run -n picrust2_env picrust2_pipeline.py \
  -i /content/millet_otu_table.txt \
  -s /content/cleaned_millet.fasta \
  -o /content/picrust2_output \
  -p 1 \
  --placement_tool sepp
# Out:
# All ASVs were below the max NSTI cut-off of 2.0 and so all were retained for downstream analyses.
#
# All ASVs were below the max NSTI cut-off of 2.0 and so all were retained for downstream analyses.

# %%
# !zip -r picrust2_output.zip /content/picrust2_output
# Out:
#   adding: content/picrust2_output/ (stored 0%)
#   adding: content/picrust2_output/KO_metagenome_out/ (stored 0%)
#   adding: content/picrust2_output/KO_metagenome_out/seqtab_norm.tsv.gz (stored 0%)
#   adding: content/picrust2_output/KO_metagenome_out/weighted_nsti.tsv.gz (stored 0%)
#   adding: content/picrust2_output/KO_metagenome_out/pred_metagenome_unstrat.tsv.gz (stored 0%)
#   adding: content/picrust2_output/pathways_out/ (stored 0%)
#   adding: content/picrust2_output/pathways_out/path_abun_unstrat.tsv.gz (stored 0%)
#   adding: content/picrust2_output/out.tre (deflated 70%)
#   adding: content/picrust2_output/EC_metagenome_out/ (stored 0%)
#   adding: content/picrust2_output/EC_metagenome_out/seqtab_norm.tsv.gz (stored 0%)
#   adding: content/picrust2_output/EC_metagenome_out/weighted_nsti.tsv.gz (stored 0%)
#   adding: content/picrust2_output/EC_metagenome_out/pred_metagenome_unstrat.tsv.gz (stored 0%)
# ...
